# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
# %matplotlib inline

# %%
df = pd.read_excel('data.xlsx')
df.head()
# Out:
#   Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008     3.723590            7.168690        0.450662
# 1  Afghanistan  2009     4.401778            7.333790        0.552308
# 2  Afghanistan  2010     4.758381            7.386629        0.539075
# 3  Afghanistan  2011     3.831719            7.415019        0.521104
# 4  Afghanistan  2012     3.782938            7.517126        0.520637
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         50.799999                      0.718114    0.177889
# 1                         51.200001                      0.678896    0.200178
# 2                         51.599998                      0.600127    0.134353
# 3                         51.919998                      0.495901    0.172137
# 4                         52.240002                      0.530935    0.244273
#
#    Perceptions of corruption  Positive affect  Negative affect  \
# 0                   0.881686         0.517637         0.258195
# 1                   0.850035         0.583926         0.237092
# 2                   0.706766         0.618265         0.275324
# 3                   0.731109         0.611387         0.267175
# 4                   0.775620         0.710385         0.267919
#
#    Confidence in national government  Democratic Quality  Delivery Quality
# 0                           0.612072           -1.929690         -1.655084
# 1                           0.611545           -2.044093         -1.635025
# 2                           0.299357           -1.991810         -1.617176
# 3                           0.307386           -1.919018         -1.616221
# 4                           0.435440           -1.842996         -1.404078

# %%
df.isnull().sum()
# Out:
# Country name                           0
# Year                                   0
# Life Ladder                            0
# Log GDP per capita                    28
# Social support                        13
# Healthy life expectancy at birth      28
# Freedom to make life choices          29
# Generosity                            82
# Perceptions of corruption             96
# Positive affect                       19
# Negative affect                       13
# Confidence in national government    174
# Democratic Quality                   146
# Delivery Quality                     145
# dtype: int64

# %%
df = df.fillna(method = 'ffill')
df.describe()
# Out:
#               Year  Life Ladder  Log GDP per capita  Social support  \
# count  1704.000000  1704.000000         1704.000000     1704.000000
# mean   2012.332160     5.437155            9.226700        0.811116
# std       3.688072     1.121149            1.186344        0.119077
# min    2005.000000     2.661718            6.457201        0.290184
# 25%    2009.000000     4.610970            8.312990        0.748136
# 50%    2012.000000     5.339557            9.410063        0.833999
# 75%    2015.000000     6.273522           10.211779        0.904498
# max    2018.000000     8.018934           11.770276        0.987343
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       1704.000000                   1704.000000
# mean                          63.059356                      0.734016
# std                            7.602807                      0.144426
# min                           32.299999                      0.257534
# 25%                           58.275000                      0.638466
# 50%                           64.980003                      0.753022
# 75%                           68.300003                      0.848297
# max                           76.800003                      0.985178
#
#         Generosity  Perceptions of corruption  Positive affect  \
# count  1704.000000                1704.000000      1704.000000
# mean     -0.000965                   0.745757         0.709171
# std       0.162508                   0.188081         0.107986
# min      -0.336385                   0.035198         0.362498
# 25%      -0.119477                   0.690116         0.621785
# 50%      -0.023286                   0.803599         0.718486
# 75%       0.092054                   0.870097         0.800261
# max       0.677743                   0.983276         0.943621
#
#        Negative affect  Confidence in national government  Democratic Quality  \
# count      1704.000000                        1704.000000         1704.000000
# mean          0.265984                           0.494958           -0.142519
# std           0.084586                           0.203924            0.878422
# min           0.083426                           0.068769           -2.448228
# 25%           0.205834                           0.339843           -0.796681
# 50%           0.254965                           0.471506           -0.232576
# 75%           0.315848                           0.631961            0.646006
# max           0.704590                           0.993604            1.575009
#
#        Delivery Quality
# count       1704.000000
# mean          -0.008758
# std            0.979057
# min           -2.144974
# 25%           -0.717207
# 50%           -0.221058
# 75%            0.694377
# max            2.184725

# %%
df['Country name'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Bahrain',
#        'Bangladesh', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan',
#        'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo (Brazzaville)', 'Congo (Kinshasa)',
#        'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Estonia', 'Ethiopia', 'Finland', 'France', 'Gabon',
#        'Gambia', 'Georgia', 'Germany', 'Ghana', 'Greece', 'Guatemala',
#        'Guinea', 'Guyana', 'Haiti', 'Honduras',
#        'Hong Kong S.A.R. of China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
#        'Ivory Coast', 'Jamaica', 'Japan', 'Jordan', 'Kazakhstan', 'Kenya',
#        'Kosovo', 'Kuwait', 'Kyrgyzstan', 'Laos', 'Latvia', 'Lebanon',
#        'Lesotho', 'Liberia', 'Libya', 'Lithuania', 'Luxembourg',
#        'Macedonia', 'Madagascar', 'Malawi', 'Malaysia', 'Mali', 'Malta',
#        'Mauritania', 'Mauritius', 'Mexico', 'Moldova', 'Mongolia',
#        'Montenegro', 'Morocco', 'Mozambique', 'Myanmar', 'Namibia',
#        'Nepal', 'Netherlands', 'New Zealand', 'Nicaragua', 'Niger',
#        'Nigeria', 'North Cyprus', 'Norway', 'Oman', 'Pakistan',
#        'Palestinian Territories', 'Panama', 'Paraguay', 'Peru',
#        'Philippines', 'Poland', 'Portugal', 'Qatar', 'Romania', 'Russia',
#        'Rwanda', 'Saudi Arabia', 'Senegal', 'Serbia', 'Sierra Leone',
#        'Singapore', 'Slovakia', 'Slovenia', 'Somalia',
#        'Somaliland region', 'South Africa', 'South Korea', 'South Sudan',
#        'Spain', 'Sri Lanka', 'Sudan', 'Suriname', 'Swaziland', 'Sweden',
#        'Switzerland', 'Syria', 'Taiwan Province of China', 'Tajikistan',
#        'Tanzania', 'Thailand', 'Togo', 'Trinidad and Tobago', 'Tunisia',
#        'Turkey', 'Turkmenistan', 'Uganda', 'Ukraine',
#        'United Arab Emirates', 'United Kingdom', 'United States',
#        'Uruguay', 'Uzbekistan', 'Venezuela', 'Vietnam', 'Yemen', 'Zambia',
#        'Zimbabwe'], dtype=object)

# %%
"""1. How happiness in some countries change through years?
2. Predit happiness and actual happiness in some countries? (linear regression)
3. How factors affect to ranking score? (Kmeans clusters)"""
# Out:
# '1. How happiness in some countries change through years?\n2. Predit happiness and actual happiness in some countries? (linear regression)\n3. How factors affect to ranking score? (Kmeans clusters)'

# %%
df.sample(10)
# Out:
#                  Country name  Year  Life Ladder  Log GDP per capita  \
# 1567                  Ukraine  2006     4.803954            8.965472
# 1664                  Vietnam  2015     5.076315            8.622428
# 481                  Ethiopia  2015     4.573155            7.335052
# 1599           United Kingdom  2014     6.758148           10.551946
# 1309                   Serbia  2010     4.461304            9.448421
# 234                  Cambodia  2008     4.462164            7.804773
# 1166  Palestinian Territories  2018     4.553922                 NaN
# 905                 Macedonia  2017     5.233867            9.481223
# 841                    Latvia  2016     5.940446           10.075054
# 1508                 Thailand  2018     6.011562            9.734829
#
#       Social support  Healthy life expectancy at birth  \
# 1567        0.852453                         60.119999
# 1664        0.848677                         67.300003
# 481         0.625597                         57.000000
# 1599        0.910247                         71.620003
# 1309        0.725563                         66.199997
# 234         0.619264                         56.900002
# 1166        0.819479                               NaN
# 905         0.799955                         67.300003
# 841         0.917074                         66.199997
# 1508        0.873052                         67.199997
#
#       Freedom to make life choices  Generosity  Perceptions of corruption  \
# 1567                      0.623814   -0.237178                   0.929431
# 1664                           NaN    0.087423                        NaN
# 481                       0.802643    0.118702                   0.567027
# 1599                      0.857040    0.350521                   0.484118
# 1309                      0.462647   -0.172067                   0.965472
# 234                       0.914173    0.044641                   0.888392
# 1166                      0.654535         NaN                   0.813780
# 905                       0.752107   -0.057992                   0.855697
# 841                       0.685299   -0.159757                   0.867640
# 1508                      0.904828    0.251650                   0.906596
#
#       Positive affect  Negative affect  Confidence in national government  \
# 1567         0.621520         0.249234                           0.154709
# 1664         0.642237         0.232416                                NaN
# 481          0.713888         0.236629                           0.826341
# 1599         0.793993         0.251140                           0.422672
# 1309         0.532202         0.415409                                NaN
# 234          0.739183         0.335324                           0.737532
# 1166         0.610405         0.418929                           0.392373
# 905          0.502460         0.299391                           0.442916
# 841          0.653751         0.231384                           0.315261
# 1508         0.843489         0.198190                           0.605364
#
#       Democratic Quality  Delivery Quality
# 1567            0.006907         -0.640157
# 1664           -0.644411         -0.295184
# 481            -1.398238         -0.659262
# 1599            0.845569          1.770141
# 1309           -0.067638         -0.184058
# 234            -0.635804         -0.953722
# 1166                 NaN               NaN
# 905            -0.194677          0.024050
# 841             0.660759          0.869054
# 1508                 NaN               NaN

# %%
df.columns
# Out:
# Index(['Country name', 'Year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect',
#        'Confidence in national government', 'Democratic Quality',
#        'Delivery Quality'],
#       dtype='object')

# %%
df_2018 = df[df.Year == 2018]
df_2018.head(20)
# Out:
#                Country name  Year  Life Ladder  Log GDP per capita  \
# 10              Afghanistan  2018     2.694303            7.494588
# 21                  Albania  2018     5.004403            9.412399
# 28                  Algeria  2018     5.043086            9.557952
# 45                Argentina  2018     5.792797            9.809972
# 58                  Armenia  2018     5.062449            9.119424
# 70                Australia  2018     7.176993           10.721021
# 81                  Austria  2018     7.396002           10.741893
# 94               Azerbaijan  2018     5.167995            9.678014
# 116              Bangladesh  2018     4.499217            8.220746
# 129                 Belarus  2018     5.233770            9.778739
# 141                 Belgium  2018     6.892172           10.672445
# 153                   Benin  2018     5.819827            7.663907
# 169                 Bolivia  2018     5.915734            8.860531
# 180  Bosnia and Herzegovina  2018     5.887401            9.402726
# 191                Botswana  2018     3.461366            9.680226
# 204                  Brazil  2018     6.190922            9.557933
# 214                Bulgaria  2018     5.098814            9.873219
# 226            Burkina Faso  2018     4.927236            7.470520
# 231                 Burundi  2018     3.775283            6.541033
# 244                Cambodia  2018     5.121838            8.253352
#
#      Social support  Healthy life expectancy at birth  \
# 10         0.507516                         52.599998
# 21         0.683592                         68.699997
# 28         0.798651                         65.900002
# 45         0.899912                         68.800003
# 58         0.814449                         66.900002
# 70         0.940137                         73.599998
# 81         0.911668                         73.000000
# 94         0.781230                         65.500000
# 116        0.705556                         64.300003
# 129        0.904569                         66.099998
# 141        0.929816                         72.000000
# 153        0.503544                         54.299999
# 169        0.827159                         63.599998
# 180        0.835890                         67.800003
# 191        0.794936                         58.900002
# 204        0.881505                         66.400002
# 214        0.923853                         66.800003
# 226        0.664859                         53.900002
# 231        0.484715                         53.400002
# 244        0.794605                         61.599998
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 10                       0.373536   -0.084888                   0.927606
# 21                       0.824212    0.005385                   0.899129
# 28                       0.583381   -0.172413                   0.758704
# 45                       0.845895   -0.206937                   0.855255
# 58                       0.807644   -0.149109                   0.676826
# 70                       0.916028    0.137795                   0.404647
# 81                       0.904112    0.051552                   0.523061
# 94                       0.772449   -0.251795                   0.561206
# 116                      0.901471   -0.038008                   0.701421
# 129                      0.643602   -0.181865                   0.718455
# 141                      0.808387   -0.127278                   0.630412
# 153                      0.713264    0.024661                   0.746511
# 169                      0.863247   -0.087568                   0.786045
# 180                      0.658846    0.124627                   0.912858
# 191                      0.817621   -0.259084                   0.806945
# 204                      0.750609   -0.126327                   0.763251
# 214                      0.724336   -0.179110                   0.952014
# 226                      0.720743   -0.004381                   0.757399
# 231                      0.646399   -0.019334                   0.598608
# 244                      0.958305    0.033787                        NaN
#
#      Positive affect  Negative affect  Confidence in national government  \
# 10          0.424125         0.404904                           0.364666
# 21          0.713300         0.318997                           0.435338
# 28          0.591043         0.292946                                NaN
# 45          0.820310         0.320502                           0.261352
# 58          0.581488         0.454840                           0.670828
# 70          0.759019         0.187456                           0.468837
# 81          0.752350         0.226059                           0.488679
# 94          0.592575         0.191392                           0.834372
# 116         0.541345         0.361238                           0.831693
# 129         0.450333         0.235729                           0.421279
# 141         0.749563         0.250297                           0.441945
# 153         0.646655         0.467872                           0.639220
# 169         0.741973         0.387469                           0.399588
# 180         0.642940         0.277365                           0.254097
# 191         0.729643         0.267084                           0.718788
# 204         0.749728         0.349656                           0.168187
# 214         0.639022         0.189091                           0.218996
# 226         0.710884         0.342866                           0.622255
# 231         0.666442         0.362767                                NaN
# 244         0.844593         0.414346                                NaN
#
#      Democratic Quality  Delivery Quality
# 10                  NaN               NaN
# 21                  NaN               NaN
# 28                  NaN               NaN
# 45                  NaN               NaN
# 58                  NaN               NaN
# 70                  NaN               NaN
# 81                  NaN               NaN
# 94                  NaN               NaN
# 116                 NaN               NaN
# 129                 NaN               NaN
# 141                 NaN               NaN
# 153                 NaN               NaN
# 169                 NaN               NaN
# 180                 NaN               NaN
# 191                 NaN               NaN
# 204                 NaN               NaN
# 214                 NaN               NaN
# 226                 NaN               NaN
# 231                 NaN               NaN
# 244                 NaN               NaN

# %%
usa = df[df['Country name'] == 'United States']
usa.reset_index(inplace = True)
del usa['index']
usa
# Out:
#      Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0   United States  2006     7.181794           10.831686        0.964572
# 1   United States  2007     7.512688           10.839805             NaN
# 2   United States  2008     7.280386           10.827426        0.952587
# 3   United States  2009     7.158032           10.790511        0.911794
# 4   United States  2010     7.163616           10.807183        0.926159
# 5   United States  2011     7.115139           10.815644        0.921705
# 6   United States  2012     7.026227           10.830132        0.903192
# 7   United States  2013     7.249285           10.839653        0.925397
# 8   United States  2014     7.151114           10.857497        0.902097
# 9   United States  2015     6.863947           10.878154        0.903571
# 10  United States  2016     6.803600           10.885554        0.896751
# 11  United States  2017     6.991759           10.900906        0.921003
# 12  United States  2018     6.882685           10.922465        0.903856
#
#     Healthy life expectancy at birth  Freedom to make life choices  \
# 0                          68.059998                      0.911496
# 1                          68.220001                      0.871904
# 2                          68.379997                      0.877956
# 3                          68.540001                      0.830684
# 4                          68.699997                      0.828044
# 5                          68.680000                      0.863202
# 6                          68.660004                      0.822662
# 7                          68.639999                      0.792256
# 8                          68.620003                      0.866077
# 9                          68.599998                      0.848753
# 10                         68.500000                      0.757893
# 11                         68.400002                      0.868497
# 12                         68.300003                      0.824607
#
#     Generosity  Perceptions of corruption  Positive affect  Negative affect  \
# 0          NaN                   0.600309         0.827417         0.260511
# 1     0.188272                   0.633035         0.828503         0.231679
# 2     0.246029                   0.668495         0.871968         0.226823
# 3     0.192269                   0.665394         0.843484         0.261661
# 4     0.235522                   0.689583         0.860642         0.231053
# 5     0.152239                   0.696926         0.836360         0.273379
# 6     0.206243                   0.710034         0.833771         0.259644
# 7     0.265563                   0.746894         0.813678         0.260328
# 8     0.212869                   0.702267         0.834294         0.281265
# 9     0.210956                   0.697543         0.813908         0.274688
# 10    0.135592                   0.738920         0.805674         0.264204
# 11    0.188833                   0.681191         0.826555         0.268269
# 12    0.107713                   0.709928         0.815383         0.292226
#
#     Confidence in national government  Democratic Quality  Delivery Quality
# 0                            0.558029            0.797783          1.546490
# 1                            0.393245            0.742770          1.539012
# 2                            0.379221            0.864745          1.559145
# 3                            0.503047            0.772818          1.450143
# 4                            0.418276            0.786005          1.478330
# 5                            0.382532            0.859107          1.462401
# 6                            0.348856            0.897015          1.467070
# 7                            0.288648            0.873046          1.415544
# 8                            0.348671            0.826821          1.433888
# 9                            0.346936            0.893903          1.428245
# 10                           0.297206            0.755765          1.491426
# 11                           0.386535            0.677056          1.552135
# 12                           0.313816                 NaN               NaN

# %%
sns.stripplot(x = 'Year',
           y = 'Life Ladder',
        df = usa)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-8c0273bf0d81> in <module>
#       1 sns.stripplot(x = 'Year',
#       2            y = 'Life Ladder',
# ----> 3         df = usa)
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in stripplot(x, y, hue, data, order, hue_order, jitter, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2776
#    2777     plotter = _StripPlotter(x, y, hue, data, order, hue_order,
# -> 2778                             jitter, dodge, orient, color, palette)
#    2779     if ax is None:
#    2780         ax = plt.gca()
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, jitter, dodge, orient, color, palette)
#    1141                  jitter, dodge, orient, color, palette):
#    1142         """Initialize the plotter."""
# -> 1143         self.establish_variables(x, y, hue, data, orient, order, hue_order)
#    1144         self.establish_colors(color, palette, 1)
#    1145
#
# ~/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153                 if isinstance(input, string_types):
#     154                     err = "Could not interpret input '{}'".format(input)
# --> 155                     raise ValueError(err)
#     156
#     157             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'Year'

# %%
plt.bar(df['Year'],
        df['Life Ladder'], color = 'g')
# Out:
# <BarContainer object of 1704 artists>

# %%
countries = ['United States', 'India', 'France', 'South Africa', 'Brazil']
some_countries1 = df['Year'].isin([2018])
some_countries2 = df['Country name'].isin(countries)
some_countries[some_countries1 & some_countries2]
# Out:
# 204     True
# 508     True
# 653     True
# 1381    True
# 1616    True
# Name: Country name, dtype: bool

# %%
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# Name: Country name, dtype: bool
