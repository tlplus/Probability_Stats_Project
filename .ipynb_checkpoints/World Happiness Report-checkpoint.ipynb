# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %matplotlib inline

# %%
df = pd.read_excel('data.xlsx')
df.head()
# Out:
#   Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 0  Afghanistan  2008     3.723590            7.168690        0.450662
# 1  Afghanistan  2009     4.401778            7.333790        0.552308
# 2  Afghanistan  2010     4.758381            7.386629        0.539075
# 3  Afghanistan  2011     3.831719            7.415019        0.521104
# 4  Afghanistan  2012     3.782938            7.517126        0.520637
#
#    Healthy life expectancy at birth  Freedom to make life choices  Generosity  \
# 0                         50.799999                      0.718114    0.177889
# 1                         51.200001                      0.678896    0.200178
# 2                         51.599998                      0.600127    0.134353
# 3                         51.919998                      0.495901    0.172137
# 4                         52.240002                      0.530935    0.244273
#
#    Perceptions of corruption  Positive affect  Negative affect  \
# ...

# %%
df.isnull().sum()
# Out:
# Country name                           0
# Year                                   0
# Life Ladder                            0
# Log GDP per capita                    28
# Social support                        13
# Healthy life expectancy at birth      28
# Freedom to make life choices          29
# Generosity                            82
# Perceptions of corruption             96
# Positive affect                       19
# Negative affect                       13
# Confidence in national government    174
# dtype: int64

# %%
"df = df.fillna(method = 'ffill')"
df.describe()
# Out:
#               Year  Life Ladder  Log GDP per capita  Social support  \
# count  1704.000000  1704.000000         1676.000000     1691.000000
# mean   2012.332160     5.437155            9.222456        0.810570
# std       3.688072     1.121149            1.185794        0.119210
# min    2005.000000     2.661718            6.457201        0.290184
# 25%    2009.000000     4.610970            8.304428        0.747512
# 50%    2012.000000     5.339557            9.406206        0.833098
# 75%    2015.000000     6.273522           10.193060        0.904432
# max    2018.000000     8.018934           11.770276        0.987343
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       1676.000000                   1675.000000
# mean                          63.111971                      0.733829
# std                            7.583622                      0.144115
# min                           32.299999                      0.257534
# ...

# %%
df['Country name'].unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Angola', 'Argentina',
#        'Armenia', 'Australia', 'Austria', 'Azerbaijan', 'Bahrain',
#        'Bangladesh', 'Belarus', 'Belgium', 'Belize', 'Benin', 'Bhutan',
#        'Bolivia', 'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'Bulgaria', 'Burkina Faso', 'Burundi', 'Cambodia', 'Cameroon',
#        'Canada', 'Central African Republic', 'Chad', 'Chile', 'China',
#        'Colombia', 'Comoros', 'Congo (Brazzaville)', 'Congo (Kinshasa)',
#        'Costa Rica', 'Croatia', 'Cuba', 'Cyprus', 'Czech Republic',
#        'Denmark', 'Djibouti', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Estonia', 'Ethiopia', 'Finland', 'France', 'Gabon',
#        'Gambia', 'Georgia', 'Germany', 'Ghana', 'Greece', 'Guatemala',
#        'Guinea', 'Guyana', 'Haiti', 'Honduras',
#        'Hong Kong S.A.R. of China', 'Hungary', 'Iceland', 'India',
#        'Indonesia', 'Iran', 'Iraq', 'Ireland', 'Israel', 'Italy',
# ...

# %%
"""1. How happiness in some countries change through years?
2. Predit happiness and actual happiness in some countries? (linear regression)
3. How factors affect to ranking score? (Kmeans clusters)"""
# Out:
# '1. How happiness in some countries change through years?\n2. Predit happiness and actual happiness in some countries? (linear regression)\n3. How factors affect to ranking score? (Kmeans clusters)'

# %%
#Randomly selecting 10 countries
df.sample(10)
# Out:
#              Country name  Year  Life Ladder  Log GDP per capita  \
# 850               Lebanon  2012     4.572567            9.619617
# 734               Jamaica  2011     5.374446            8.999516
# 353            Costa Rica  2009     7.614929            9.436996
# 1271               Rwanda  2008     4.362989            7.141650
# 340   Congo (Brazzaville)  2017     4.883991            8.493189
# 476               Estonia  2017     5.938396           10.291510
# 308                 China  2012     5.094917            9.318813
# 97                Bahrain  2011     4.823976           10.600740
# 594                 Haiti  2011     4.844574            7.353901
# 1131         North Cyprus  2018     5.608056                 NaN
#
#       Social support  Healthy life expectancy at birth  \
# 850         0.712611                         65.360001
# 734         0.854584                         66.220001
# 353         0.899782                         69.760002
# ...

# %%
df.columns
# Out:
# Index(['Country name', 'Year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect',
#        'Confidence in national government'],
#       dtype='object')

# %%
# Data of 2018 only

df_2018 = df[df.Year == 2018]
df_2018.head(20)
# Out:
#                Country name  Year  Life Ladder  Log GDP per capita  \
# 10              Afghanistan  2018     2.694303            7.494588
# 21                  Albania  2018     5.004403            9.412399
# 28                  Algeria  2018     5.043086            9.557952
# 45                Argentina  2018     5.792797            9.809972
# 58                  Armenia  2018     5.062449            9.119424
# 70                Australia  2018     7.176993           10.721021
# 81                  Austria  2018     7.396002           10.741893
# 94               Azerbaijan  2018     5.167995            9.678014
# 116              Bangladesh  2018     4.499217            8.220746
# 129                 Belarus  2018     5.233770            9.778739
# 141                 Belgium  2018     6.892172           10.672445
# 153                   Benin  2018     5.819827            7.663907
# 169                 Bolivia  2018     5.915734            8.860531
# ...

# %%
sns.pairplot(df_2018)
# Out:
# /Users/tl/anaconda3/lib/python3.6/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Users/tl/anaconda3/lib/python3.6/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
"""Happiness score distribution since 2008 v 2018"""

plt.figure(figsize = (16, 12))

"""plt.subplot(2, 1, 1)
sns.distplot(df['Life Ladder'], color = 'green')
plt.title('2008 - 2018')
plt.ylabel('Life Ladder')

plt.subplot(2, 1, 2)
sns.distplot(df_2018['Life Ladder'], color = 'orange')
plt.title('2018')
plt.ylabel('Life Ladder')"""


data = [df, df_2018]
n = 1
for i in data:
    plt.subplot(2, 1, n)
    sns.distplot(i['Life Ladder'],
                color = 'green' if n == 1 else 'orange')
    plt.title('2008 - 2018' if n == 1 else '2018')
    plt.ylabel('Life Ladder')
    n+=1

# %% [markdown]
# Analyze some factors to see if it impacts to the happiness score

# %%
plt.figure(figsize = (20, 20))
factors_2018 = ['Log GDP per capita', 'Healthy life expectancy at birth',
               'Freedom to make life choices', 'Social support']
for i, j in zip(range(1, 5), factors_2018):
    plt.subplot(4, 1, i)
    plt.scatter(df_2018['Life Ladder'], df_2018[j], c=np.random.rand(3,))
    plt.title(j)
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...

# %% [markdown]
# Looking at the charts, we can these factors all impact the score

# %% [markdown]
# GDP per capita and Healthy life

# %%
plt.figure(figsize = (15, 8))
plt.scatter(df_2018['Log GDP per capita'],
            df_2018['Healthy life expectancy at birth'],
            s = df_2018['Life Ladder']**3.5,
            alpha = 0.3,
            c='purple')
plt.title('Economy and Family Life', size = 20)
plt.xlabel('Log of GDP per capita')
plt.ylabel('Healthy life expectancy at birth')
# Out:
# Text(0, 0.5, 'Healthy life expectancy at birth')

# %%
usa = df[df['Country name'] == 'United States']
france = df[df['Country name'] == 'France']
south_africa = df[df['Country name'] == 'South Africa']
brazil = df[df['Country name'] == 'Brazil']

# %%
"""Year and Life Ladder of some countries"""
ax, fig = plt.subplots(figsize = (10, 6))

life_ladder = [usa, france, south_africa, brazil]
life_ladder2 = ['United States', 'France', 'South Africa', 'Brazil']
color = ['red', 'green', 'blue', 'orange']
for i, j in zip(life_ladder, color):
    #plt.plot(i['Year'], i['Life Ladder'], 'ro')
    sns.lineplot(x = 'Year',
                 y = 'Life Ladder',
                 color = j,
                 alpha = 0.3,
                 data = i)
    plt.ylim(6, 8)
    plt.legend(life_ladder2)

# %%
# Data of United States 
usa
# Out:
#        Country name  Year  Life Ladder  Log GDP per capita  Social support  \
# 1604  United States  2006     7.181794           10.831686        0.964572
# 1605  United States  2007     7.512688           10.839805             NaN
# 1606  United States  2008     7.280386           10.827426        0.952587
# 1607  United States  2009     7.158032           10.790511        0.911794
# 1608  United States  2010     7.163616           10.807183        0.926159
# 1609  United States  2011     7.115139           10.815644        0.921705
# 1610  United States  2012     7.026227           10.830132        0.903192
# 1611  United States  2013     7.249285           10.839653        0.925397
# 1612  United States  2014     7.151114           10.857497        0.902097
# 1613  United States  2015     6.863947           10.878154        0.903571
# 1614  United States  2016     6.803600           10.885554        0.896751
# ...

# %% [markdown]
# # Predict United States Life Ladder score next years
#
# Using Linear Regression model from Scikit-learn library.

# %%
x = usa[['Year']]
y = usa['Life Ladder']

# %%
from sklearn import linear_model
reg_usa = linear_model.LinearRegression()
reg_usa.fit(x, y)
reg_usa.score(x, y)
# Out:
# 0.6125847423723318

# %%
ax, fig = plt.subplots(figsize = (15, 10))
plt.scatter(usa['Year'], usa['Life Ladder'], s = 100, c = 'r')
plt.plot(x, reg_usa.predict(x))
plt.xlabel('Year', size = 20)
plt.ylabel('Life Ladder', size = 20)
plt.title('Predict Happiness Score and Actual Happiness Score', size = 20)
# Out:
# Text(0.5, 1.0, 'Predict Happiness Score and Actual Happiness Score')

# %% [markdown]
# Seems like the United States' life ladder will continue declicing for next several years according to World Happiness Report's current data.

# %% [markdown]
# Trying to use other regresssion model such as Support Vector Machine Regression and Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
rf.fit(x, y)
rf.score(x, y)
# Out:
# /Users/tl/anaconda3/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# 0.8525995208540358

# %%
from sklearn.svm import SVR
sv = SVR()
sv.fit(x, y)
sv.score(x, y)
# Out:
# /Users/tl/anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py:196: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.8335703346517114

# %%
ax, fig = plt.subplots(figsize = (15, 10))
plt.scatter(usa['Year'], usa['Life Ladder'], s = 100, c = 'r')
plt.plot(x, reg_usa.predict(x))
plt.plot(x, rf.predict(x))
plt.plot(x, sv.predict(x))
plt.xlabel('Year', size = 20)
plt.ylabel('Life Ladder', size = 20)
plt.title('Predict Happiness Score and Actual Happiness Score', size = 2)
plt.legend(["Linear Regression", "Random Forest Regression", "SVR"])

# %% [markdown]
# This is how it's predicted using Support Vector Machine Regression and Random Forest Regression, it's more accurate than Linear Regression

# %% [markdown]
# # How factors affect each other?
# # Let's see how economy and corruption affect each other.

# %%
df_2018 = df_2018.fillna(method = 'ffill')
#Fill some data missing by average them

# %% [markdown]
# Using cluster from skit-learn to see how these factors are grouped.

# %%
from sklearn.cluster import KMeans

X = df_2018[['Log GDP per capita', 'Perceptions of corruption']]
km_iner = []
for i in range(1, 8):
    km = KMeans(n_clusters = i)
    km.fit(X)
    km_iner.append(km.inertia_)

# %% [markdown]
# First, we need to use elbow point to choose number of clusters

# %%
ax, figsize = plt.subplots(figsize = (20, 6))
plt.plot(range(1, 8), km_iner, 'ro')
# range(1, 12) = np.arange(1, 12)
plt.plot(np.arange(1, 8), km_iner, '-', alpha = 0.3)
plt.xlabel('Number of clusters')
# Out:
# Text(0.5, 0, 'Number of clusters')

# %% [markdown]
# From the graph, cluster = 2 and = 3 are chosen

# %%
ax, figsize = plt.subplots(figsize = (10, 14))

n_clus = [2, 3]
n = 1
for i in n_clus:
    kmeans = KMeans(n_clusters = i)
    kmeans.fit(X)
    y_kmeans = kmeans.predict(X)
    centers = kmeans.cluster_centers_
    
    plt.subplot(2, 1, n)
    
    plt.scatter(df_2018['Log GDP per capita'],
            df_2018['Perceptions of corruption'],
            c=y_kmeans, s=100, alpha = 0.5, cmap='rainbow')
    plt.scatter(centers[:, 0], centers[:,1], c = 'yellow', s = 200, alpha = 0.5)
    plt.xlabel('Log of GDP')
    plt.ylabel('Corruption')
    plt.title('Clusters = 2' if n == 1 else 'Clusters = 3')
    n+=1

# %% [markdown]
# Conclusion:
#
# Clusters = 2: The economies are slow, the more corruption. Meanwhile the GPD is higher, the corruption is less.
#
# Cluster = 3: The economies are slow and developing tend to have more corruption than developed economies.
